# %% [markdown]
# ### Importing necessery `libraries`

# %%
from bs4 import BeautifulSoup
import requests
import json
import time
import pandas as pd

# %% [markdown]
# ### Defining `functions` to make `requests` and `pulling` data out of HTML

# %%
def MakingRequest(url: str) -> str:
    r = requests.get(URL)
    if r.status_code == 200:
        soup = BeautifulSoup(r.text, 'html.parser')
        print("\033[92m Request was successfully done. The status code: {}".format(r.status_code))
        USDollarExchangeRateTable = soup.find_all('td')
        Time = soup.find_all('span', class_="ratesTimestamp")[0].text
        USDollar = soup.find_all('th', class_='rtHeader rtHeaderCurr')[0].text
        ValueUSDollar = soup.find_all('th', class_='rtHeader rtHeaderValues')[0].text
        return USDollarExchangeRateTable, Time, USDollar, ValueUSDollar
    else:   
        print(f"\033[91m Request wasn't successfully done. The status code: {r.status_code}")


URL = 'https://www.x-rates.com/table/?from=USD&amount=1'
r = requests.get(URL)
soup = BeautifulSoup(r.text, 'html.parser')
MakingRequest(URL)
# Out:
#  Request was successfully done. The status code: 200
# ([<td>Euro</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=EUR">0.906298</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=EUR&amp;to=USD">1.103389</a></td>,
#   <td>British Pound</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=GBP">0.787633</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=GBP&amp;to=USD">1.269626</a></td>,
#   <td>Indian Rupee</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=INR">83.163115</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=INR&amp;to=USD">0.012025</a></td>,
#   <td>Australian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=AUD">1.470386</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=AUD&amp;to=USD">0.680094</a></td>,
#   <td>Canadian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CAD">1.325575</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CAD&amp;to=USD">0.754390</a></td>,
#   <td>Singapore Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=SGD">1.324306</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=SGD&amp;to=USD">0.755112</a></td>,
#   <td>Swiss Franc</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CHF">0.856479</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CHF&amp;to=USD">1.167571</a></td>,
#   <td>Malaysian Ringgit</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=MYR">4.631911</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=MYR&amp;to=USD">0.215894</a></td>,
#   <td>Japanese Yen</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=JPY">142.430264</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=JPY&amp;to=USD">0.007021</a></td>,
#   <td>Chinese Yuan Renminbi</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CNY">7.131324</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CNY&amp;to=USD">0.140226</a></td>,
#   <td>Argentine Peso</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=ARS">804.634116</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=ARS&amp;to=USD">0.001243</a></td>,
#   <td>Australian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=AUD">1.470386</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=AUD&amp;to=USD">0.680094</a></td>,
#   <td>Bahraini Dinar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BHD">0.376000</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BHD&amp;to=USD">2.659574</a></td>,
#   <td>Botswana Pula</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BWP">13.414387</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BWP&amp;to=USD">0.074547</a></td>,
#   <td>Brazilian Real</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BRL">4.892441</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BRL&amp;to=USD">0.204397</a></td>,
#   <td>Bruneian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BND">1.324306</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BND&amp;to=USD">0.755112</a></td>,
#   <td>Bulgarian Lev</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BGN">1.772565</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BGN&amp;to=USD">0.564154</a></td>,
#   <td>Canadian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CAD">1.325575</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CAD&amp;to=USD">0.754390</a></td>,
#   <td>Chilean Peso</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CLP">892.346111</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CLP&amp;to=USD">0.001121</a></td>,
#   <td>Chinese Yuan Renminbi</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CNY">7.131324</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CNY&amp;to=USD">0.140226</a></td>,
#   <td>Colombian Peso</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=COP">3903.770099</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=COP&amp;to=USD">0.000256</a></td>,
#   <td>Czech Koruna</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CZK">22.276496</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CZK&amp;to=USD">0.044890</a></td>,
#   <td>Danish Krone</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=DKK">6.765482</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=DKK&amp;to=USD">0.147809</a></td>,
#   <td>Euro</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to
td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=THB">34.620415</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=THB&amp;to=USD">0.028885</a></td>,
#   <td>Trinidadian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=TTD">6.805386</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=TTD&amp;to=USD">0.146942</a></td>,
#   <td>Turkish Lira</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=TRY">29.214037</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=TRY&amp;to=USD">0.034230</a></td>,
#   <td>Emirati Dirham</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=AED">3.672500</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=AED&amp;to=USD">0.272294</a></td>,
#   <td>British Pound</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=GBP">0.787633</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=GBP&amp;to=USD">1.269626</a></td>,
#   <td>Venezuelan Bolivar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=VEF">3576871.414048</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=VEF&amp;to=USD">0.000000</a></td>],
#  'Dec 25, 2023 17:27 UTC',
#  'US Dollar',
#  '1.00 USD')

# %% [markdown]
# ### Selecting data to process and create `List Comprehensions` based on it
# #### Selecting `US DOLLAR EXCHANGE RATES TABLE`

# %%
def SelectingData():
    r = requests.get(URL)
    soup = BeautifulSoup(r.text, 'html.parser')
    for Currency in soup.find_all('td'):
        print(Currency.text)
        
    currencies=soup.find_all('td')
    ListComprehension = [title.text for title in currencies]

    print(ListComprehension)

SelectingData()
# Out:
# Euro
# 0.906298
# 1.103389
# British Pound
# 0.787633
# 1.269626
# Indian Rupee
# 83.163115
# 0.012025
# Australian Dollar
# 1.470386
# 0.680094
# Canadian Dollar
# 1.325575
# 0.754390
# Singapore Dollar
# 1.324306
# 0.755112
# Swiss Franc
# 0.856479
# 1.167571
# Malaysian Ringgit
# 4.631911
# 0.215894
# Japanese Yen
# 142.430264
# 0.007021
# Chinese Yuan Renminbi
# 7.131324
# 0.140226
# Argentine Peso
# 804.634116
# 0.001243
# Australian Dollar
# 1.470386
# 0.680094
# Bahraini Dinar
# 0.376000
# 2.659574
# Botswana Pula
# 13.414387
# 0.074547
# Brazilian Real
# 4.892441
# 0.204397
# Bruneian Dollar
# 1.324306
# 0.755112
# Bulgarian Lev
# 1.772565
# 0.564154
# Canadian Dollar
# 1.325575
# 0.754390
# Chilean Peso
# 892.346111
# 0.001121
# Chinese Yuan Renminbi
# 7.131324
# 0.140226
# Colombian Peso
# 3903.770099
# 0.000256
# Czech Koruna
# 22.276496
# 0.044890
# Danish Krone
# 6.765482
# 0.147809
# Euro
# 0.906298
# 1.103389
# Hong Kong Dollar
# 7.811146
# 0.128022
# Hungarian Forint
# 345.784302
# 0.002892
# Icelandic Krona
# 136.627322
# 0.007319
# Indian Rupee
# 83.163115
# 0.012025
# Indonesian Rupiah
# 15469.018399
# 0.000065
# Iranian Rial
# 42437.688471
# 0.000024
# Israeli Shekel
# 3.612192
# 0.276840
# Japanese Yen
# 142.430264
# 0.007021
# Kazakhstani Tenge
# 457.687247
# 0.002185
# South Korean Won
# 1296.676766
# 0.000771
# Kuwaiti Dinar
# 0.307176
# 3.255460
# Libyan Dinar
# 4.803814
# 0.208168
# Malaysian Ringgit
# 4.631911
# 0.215894
# Mauritian Rupee
# 43.924478
# 0.022766
# Mexican Peso
# 17.005139
# 0.058806
# Nepalese Rupee
# 133.123356
# 0.007512
# New Zealand Dollar
# 1.587405
# 0.629959
# Norwegian Krone
# 10.201507
# 0.098025
# Omani Rial
# 0.384583
# 2.600218
# Pakistani Rupee
# 282.925993
# 0.003534
# Philippine Peso
# 55.334956
# 0.018072
# Polish Zloty
# 3.944225
# 0.253535
# Qatari Riyal
# 3.640000
# 0.274725
# Romanian New Leu
# 4.514002
# 0.221533
# Russian Ruble
# 92.411195
# 0.010821
# Saudi Arabian Riyal
# 3.750000
# 0.266667
# Singapore Dollar
# 1.324306
# 0.755112
# South African Rand
# 18.477064
# 0.054121
# Sri Lankan Rupee
# 326.098390
# 0.003067
# Swedish Krona
# 10.020693
# 0.099793
# Swiss Franc
# 0.856479
# 1.167571
# Taiwan New Dollar
# 31.133170
# 0.032120
# Thai Baht
# 34.620415
# 0.028885
# Trinidadian Dollar
# 6.805386
# 0.146942
# Turkish Lira
# 29.214037
# 0.034230
# Emirati Dirham
# 3.672500
# 0.272294
# British Pound
# 0.787633
# 1.269626
# Venezuelan Bolivar
# 3576871.414048
# 0.000000
# ['Euro', '0.906298', '1.103389', 'British Pound', '0.787633', '1.269626', 'Indian Rupee', '83.163115', '0.012025', 'Australian Dollar', '1.470386', '0.680094', 'Canadian Dollar', '1.325575', '0.754390', 'Singapore Dollar', '1.324306', '0.755112', 'Swiss Franc', '0.856479', '1.167571', 'Malaysian Ringgit', '4.631911', '0.215894', 'Japanese Yen', '142.430264', '0.007021', 'Chinese Yuan Renminbi', '7.131324', '0.140226', 'Argentine Peso', '804.634116', '0.001243', 'Australian Dollar', '1.470386', '0.680094', 'Bahraini Dinar', '0.376000', '2.659574', 'Botswana Pula', '13.414387', '0.074547', 'Brazilian Real', '4.892441', '0.204397', 'Bruneian Dollar', '1.324306', '0.755112', 'Bulgarian Lev', '1.772565', '0.564154', 'Canadian Dollar', '1.325575', '0.754390', 'Chilean Peso', '892.346111', '0.001121', 'Chinese Yuan Renminbi', '7.131324', '0.140226', 'Colombian Peso', '3903.770099', '0.000256', 'Czech Koruna', '22.276496', '0.044890', 'Danish Krone', '6.765482', '0.147809', 'Euro', '0.906298', '1.103389', 'Hong Kong Dollar', '7.811146', '0.128022', 'Hungarian Forint', '345.784302', '0.002892', 'Icelandic Krona', '136.627322', '0.007319', 'Indian Rupee', '83.163115', '0.012025', 'Indonesian Rupiah', '15469.018399', '0.000065', 'Iranian Rial', '42437.688471', '0.000024', 'Israeli Shekel', '3.612192', '0.276840', 'Japanese Yen', '142.430264', '0.007021', 'Kazakhstani Tenge', '457.687247', '0.002185', 'South Korean Won', '1296.676766', '0.000771', 'Kuwaiti Dinar', '0.307176', '3.255460', 'Libyan Dinar', '4.803814', '0.208168', 'Malaysian Ringgit', '4.631911', '0.215894', 'Mauritian Rupee', '43.924478', '0.022766', 'Mexican Peso', '17.005139', '0.058806', 'Nepalese Rupee', '133.123356', '0.007512', 'New Zealand Dollar', '1.587405', '0.629959', 'Norwegian Krone', '10.201507', '0.098025', 'Omani Rial', '0.384583', '2.600218', 'Pakistani Rupee', '282.925993', '0.003534', 'Philippine Peso', '55.334956', '0.018072', 'Polish Zloty', '3.944225', '0.253535', 'Qatari Riyal', '3.640000', '0.274725', 'Romanian New Leu', '4.514002', '0.221533', 'Russian Ruble', '92.411195', '0.010821', 'Saudi Arabian Riyal', '3.750000', '0.266667', 'Singapore Dollar', '1.324306', '0.755112', 'South African Rand', '18.477064', '0.054121', 'Sri Lankan Rupee', '326.098390', '0.003067', 'Swedish Krona', '10.020693', '0.099793', 'Swiss Franc', '0.856479', '1.167571', 'Taiwan New Dollar', '31.133170', '0.032120', 'Thai Baht', '34.620415', '0.028885', 'Trinidadian Dollar', '6.805386', '0.146942', 'Turkish Lira', '29.214037', '0.034230', 'Emirati Dirham', '3.672500', '0.272294', 'British Pound', '0.787633', '1.269626', 'Venezuelan Bolivar', '3576871.414048', '0.000000']

# %% [markdown]
# ### Placing selected data to `List Comprehension`

# %%
def SavingDataToListComprehensionCurrency(currency: list) -> list:
    return [title.text for title in currency[::3]]

currencies=soup.find_all('td')
SavingDataToListComprehensionCurrency(currencies)
ListComprehensionCurrency = SavingDataToListComprehensionCurrency(currencies)
print(ListComprehensionCurrency)
# Out:
# ['Euro', 'British Pound', 'Indian Rupee', 'Australian Dollar', 'Canadian Dollar', 'Singapore Dollar', 'Swiss Franc', 'Malaysian Ringgit', 'Japanese Yen', 'Chinese Yuan Renminbi', 'Argentine Peso', 'Australian Dollar', 'Bahraini Dinar', 'Botswana Pula', 'Brazilian Real', 'Bruneian Dollar', 'Bulgarian Lev', 'Canadian Dollar', 'Chilean Peso', 'Chinese Yuan Renminbi', 'Colombian Peso', 'Czech Koruna', 'Danish Krone', 'Euro', 'Hong Kong Dollar', 'Hungarian Forint', 'Icelandic Krona', 'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial', 'Israeli Shekel', 'Japanese Yen', 'Kazakhstani Tenge', 'South Korean Won', 'Kuwaiti Dinar', 'Libyan Dinar', 'Malaysian Ringgit', 'Mauritian Rupee', 'Mexican Peso', 'Nepalese Rupee', 'New Zealand Dollar', 'Norwegian Krone', 'Omani Rial', 'Pakistani Rupee', 'Philippine Peso', 'Polish Zloty', 'Qatari Riyal', 'Romanian New Leu', 'Russian Ruble', 'Saudi Arabian Riyal', 'Singapore Dollar', 'South African Rand', 'Sri Lankan Rupee', 'Swedish Krona', 'Swiss Franc', 'Taiwan New Dollar', 'Thai Baht', 'Trinidadian Dollar', 'Turkish Lira', 'Emirati Dirham', 'British Pound', 'Venezuelan Bolivar']

# %%
def SavingDataToListComprehensionValues(ValuesOfCurrency: list) -> list:
    return [title.text for title in ValuesOfCurrency[1::3]]

Values = soup.find_all('td')
ListComprehensionValuesOfCurrency = SavingDataToListComprehensionValues(Values)
print(ListComprehensionValuesOfCurrency)
# Out:
# ['0.906298', '0.787633', '83.163115', '1.470386', '1.325575', '1.324306', '0.856479', '4.631911', '142.430264', '7.131324', '804.634116', '1.470386', '0.376000', '13.414387', '4.892441', '1.324306', '1.772565', '1.325575', '892.346111', '7.131324', '3903.770099', '22.276496', '6.765482', '0.906298', '7.811146', '345.784302', '136.627322', '83.163115', '15469.018399', '42437.688471', '3.612192', '142.430264', '457.687247', '1296.676766', '0.307176', '4.803814', '4.631911', '43.924478', '17.005139', '133.123356', '1.587405', '10.201507', '0.384583', '282.925993', '55.334956', '3.944225', '3.640000', '4.514002', '92.411195', '3.750000', '1.324306', '18.477064', '326.098390', '10.020693', '0.856479', '31.133170', '34.620415', '6.805386', '29.214037', '3.672500', '0.787633', '3576871.414048']

# %% [markdown]
# ### Converting `List Comprehension` to `Dictionary`

# %%
def ConvertingListComprehensionToDictionary(Currency: list, Value: list) -> dict:
    my_dict = {Currency[i]: Value[i] for i in range(len(Currency))}
    return my_dict

DictionaryDataCurrencyValues = ConvertingListComprehensionToDictionary(ListComprehensionCurrency,ListComprehensionValuesOfCurrency)
ConvertingListComprehensionToDictionary(ListComprehensionCurrency,ListComprehensionValuesOfCurrency)
# Out:
# {'Euro': '0.906298',
#  'British Pound': '0.787633',
#  'Indian Rupee': '83.163115',
#  'Australian Dollar': '1.470386',
#  'Canadian Dollar': '1.325575',
#  'Singapore Dollar': '1.324306',
#  'Swiss Franc': '0.856479',
#  'Malaysian Ringgit': '4.631911',
#  'Japanese Yen': '142.430264',
#  'Chinese Yuan Renminbi': '7.131324',
#  'Argentine Peso': '804.634116',
#  'Bahraini Dinar': '0.376000',
#  'Botswana Pula': '13.414387',
#  'Brazilian Real': '4.892441',
#  'Bruneian Dollar': '1.324306',
#  'Bulgarian Lev': '1.772565',
#  'Chilean Peso': '892.346111',
#  'Colombian Peso': '3903.770099',
#  'Czech Koruna': '22.276496',
#  'Danish Krone': '6.765482',
#  'Hong Kong Dollar': '7.811146',
#  'Hungarian Forint': '345.784302',
#  'Icelandic Krona': '136.627322',
#  'Indonesian Rupiah': '15469.018399',
#  'Iranian Rial': '42437.688471',
#  'Israeli Shekel': '3.612192',
#  'Kazakhstani Tenge': '457.687247',
#  'South Korean Won': '1296.676766',
#  'Kuwaiti Dinar': '0.307176',
#  'Libyan Dinar': '4.803814',
#  'Mauritian Rupee': '43.924478',
#  'Mexican Peso': '17.005139',
#  'Nepalese Rupee': '133.123356',
#  'New Zealand Dollar': '1.587405',
#  'Norwegian Krone': '10.201507',
#  'Omani Rial': '0.384583',
#  'Pakistani Rupee': '282.925993',
#  'Philippine Peso': '55.334956',
#  'Polish Zloty': '3.944225',
#  'Qatari Riyal': '3.640000',
#  'Romanian New Leu': '4.514002',
#  'Russian Ruble': '92.411195',
#  'Saudi Arabian Riyal': '3.750000',
#  'South African Rand': '18.477064',
#  'Sri Lankan Rupee': '326.098390',
#  'Swedish Krona': '10.020693',
#  'Taiwan New Dollar': '31.133170',
#  'Thai Baht': '34.620415',
#  'Trinidadian Dollar': '6.805386',
#  'Turkish Lira': '29.214037',
#  'Emirati Dirham': '3.672500',
#  'Venezuelan Bolivar': '3576871.414048'}

# %% [markdown]
# ### Saving `dictionary` to `JSON` file

# %%
def SaveToJSONfile(data: dict) -> json:
    timestr = time.strftime("%d-%m-%Y")
    try:
        with open(timestr + '-' +'US_DOLLAR_EXCHANGE_RATES_TABLE.json', 'w') as file:
                json.dump(data, file)
    except FileNotFoundError as ex:
        print(ex)


SaveToJSONfile(DictionaryDataCurrencyValues)

# %% [markdown]
# ### Saving `JSON` file to `DataFrame`

# %%
def ConvertingDictToJSON(datadict: dict) -> json:
    JSONUSDollarExchangeRatesTable = json.dumps(datadict)
    JSONUSDollarExchangeRatesTable
    dataUSDollarExchangeRatesTable = json.loads(JSONUSDollarExchangeRatesTable) 
    return dataUSDollarExchangeRatesTable

JSONCurrencyValues = ConvertingDictToJSON(DictionaryDataCurrencyValues)
ConvertingDictToJSON(DictionaryDataCurrencyValues)
# Out:
# {'Euro': '0.906298',
#  'British Pound': '0.787633',
#  'Indian Rupee': '83.163115',
#  'Australian Dollar': '1.470386',
#  'Canadian Dollar': '1.325575',
#  'Singapore Dollar': '1.324306',
#  'Swiss Franc': '0.856479',
#  'Malaysian Ringgit': '4.631911',
#  'Japanese Yen': '142.430264',
#  'Chinese Yuan Renminbi': '7.131324',
#  'Argentine Peso': '804.634116',
#  'Bahraini Dinar': '0.376000',
#  'Botswana Pula': '13.414387',
#  'Brazilian Real': '4.892441',
#  'Bruneian Dollar': '1.324306',
#  'Bulgarian Lev': '1.772565',
#  'Chilean Peso': '892.346111',
#  'Colombian Peso': '3903.770099',
#  'Czech Koruna': '22.276496',
#  'Danish Krone': '6.765482',
#  'Hong Kong Dollar': '7.811146',
#  'Hungarian Forint': '345.784302',
#  'Icelandic Krona': '136.627322',
#  'Indonesian Rupiah': '15469.018399',
#  'Iranian Rial': '42437.688471',
#  'Israeli Shekel': '3.612192',
#  'Kazakhstani Tenge': '457.687247',
#  'South Korean Won': '1296.676766',
#  'Kuwaiti Dinar': '0.307176',
#  'Libyan Dinar': '4.803814',
#  'Mauritian Rupee': '43.924478',
#  'Mexican Peso': '17.005139',
#  'Nepalese Rupee': '133.123356',
#  'New Zealand Dollar': '1.587405',
#  'Norwegian Krone': '10.201507',
#  'Omani Rial': '0.384583',
#  'Pakistani Rupee': '282.925993',
#  'Philippine Peso': '55.334956',
#  'Polish Zloty': '3.944225',
#  'Qatari Riyal': '3.640000',
#  'Romanian New Leu': '4.514002',
#  'Russian Ruble': '92.411195',
#  'Saudi Arabian Riyal': '3.750000',
#  'South African Rand': '18.477064',
#  'Sri Lankan Rupee': '326.098390',
#  'Swedish Krona': '10.020693',
#  'Taiwan New Dollar': '31.133170',
#  'Thai Baht': '34.620415',
#  'Trinidadian Dollar': '6.805386',
#  'Turkish Lira': '29.214037',
#  'Emirati Dirham': '3.672500',
#  'Venezuelan Bolivar': '3576871.414048'}

# %%
def CreateDataFrameFromJSON(json):
    dfUSDollarExchangeRates = pd.DataFrame.from_dict(json, orient="index")
    dfUSDollarExchangeRates.reset_index(inplace=True)
    dfUSDollarExchangeRates = dfUSDollarExchangeRates.set_axis(['Currency', 'Rate'], axis=1)
    USDollar =pd.DataFrame([{'Currency':'US Dollar', 'Rate':'1.0'}]) 
    dfUSDollarExchangeRates = pd.concat([USDollar, dfUSDollarExchangeRates], ignore_index=True)
    today_ts = pd.Timestamp.today()
    dfUSDollarExchangeRates['LOADINGDATA'] = today_ts
    
    return dfUSDollarExchangeRates

dfUSDollarExchangeRates = CreateDataFrameFromJSON(JSONCurrencyValues)
CreateDataFrameFromJSON(JSONCurrencyValues)
# Out:
#                  Currency            Rate                LOADINGDATA
# 0               US Dollar             1.0 2023-12-25 18:27:08.156443
# 1                    Euro        0.906298 2023-12-25 18:27:08.156443
# 2           British Pound        0.787633 2023-12-25 18:27:08.156443
# 49     Trinidadian Dollar        6.805386 2023-12-25 18:27:08.156443
# 50           Turkish Lira       29.214037 2023-12-25 18:27:08.156443
# 51         Emirati Dirham        3.672500 2023-12-25 18:27:08.156443
# 52     Venezuelan Bolivar  3576871.414048 2023-12-25 18:27:08.156443

# %% [markdown]
# ### Saving `DataFrame` to a `.csv` file

# %%
def SaveToCSVFile(dataframe):
    timestr = time.strftime("%d-%m-%Y")
    CSV = dataframe.to_csv(timestr + '-' + 'USDollarExchangeRates.csv')
    return CSV

SaveToCSVFile(dfUSDollarExchangeRates)

# %% [markdown]
# ### Selecting data to process and create `List Comprehensions` based on it
# #### Selecting a `Percent Change in the Last 24 hours`  table

# %%
def BrowsingData():
    NameOfTable = soup.find_all(class_="ratesChangetableHdr")[0].text
    PercentageChangeCurrency = soup.find_all(class_="currencyPairUL")[0].text
    return NameOfTable, PercentageChangeCurrency

BrowsingData()
# Out:
# ('Percent Change in the Last 24 Hours',
#  '\nEUR/USD+0.26880%USD/JPY-0.01848%GBP/USD-0.00218%USD/CHF+0.01964%USD/CAD-0.13320%EUR/JPY+0.25027%AUD/USD+0.05110%CNY/USD-0.11834%\n')

# %% [markdown]
# ### Saving selected data to `List Comprehension`

# %%
def ExtractingDataAndSaveItToListComprehension(data: str) -> list:
    return [PercentageCurrencyValue.text for PercentageCurrencyValue in data]

PercentageChangeCurrency = soup.find_all(class_="currencyPairUL")[0].find_all('li')

ConversionCurrencyPercentageChange = ExtractingDataAndSaveItToListComprehension(PercentageChangeCurrency)

ExtractingDataAndSaveItToListComprehension(PercentageChangeCurrency)
# Out:
# ['EUR/USD+0.26880%',
#  'USD/JPY-0.01848%',
#  'GBP/USD-0.00218%',
#  'USD/CHF+0.01964%',
#  'USD/CAD-0.13320%',
#  'EUR/JPY+0.25027%',
#  'AUD/USD+0.05110%',
#  'CNY/USD-0.11834%']

# %% [markdown]
# ### Selecting the part of `data` to split into two `Lists Comprehension`

# %%
def ExtractingConversionCurrency(conversioncurrency: str) -> list:
    return [str(ConversionCurrency)[:7:] for ConversionCurrency in conversioncurrency]
  
ConversionCurrency = ExtractingConversionCurrency(ConversionCurrencyPercentageChange)        
ExtractingConversionCurrency(ConversionCurrencyPercentageChange)
# Out:
# ['EUR/USD',
#  'USD/JPY',
#  'GBP/USD',
#  'USD/CHF',
#  'USD/CAD',
#  'EUR/JPY',
#  'AUD/USD',
#  'CNY/USD']

# %%
def ExtractingChangePercentage(changepercentage: str) -> list:
    return [PercentageValue.text for PercentageValue in changepercentage]

PercentageChange  = soup.find_all('span', {'class':['down','up']})
ChangePercentage = ExtractingChangePercentage(PercentageChange) 
ExtractingChangePercentage(PercentageChange)
# Out:
# ['+0.26880%',
#  '-0.01848%',
#  '-0.00218%',
#  '+0.01964%',
#  '-0.13320%',
#  '+0.25027%',
#  '+0.05110%',
#  '-0.11834%']

# %% [markdown]
# ### Creating `Dictionary` based on two `Lists Comprehension`

# %%
DictionaryConversionRateChangePercentage = ConvertingListComprehensionToDictionary(ConversionCurrency,ChangePercentage) 
ConvertingListComprehensionToDictionary(ConversionCurrency,ChangePercentage)
# Out:
# {'EUR/USD': '+0.26880%',
#  'USD/JPY': '-0.01848%',
#  'GBP/USD': '-0.00218%',
#  'USD/CHF': '+0.01964%',
#  'USD/CAD': '-0.13320%',
#  'EUR/JPY': '+0.25027%',
#  'AUD/USD': '+0.05110%',
#  'CNY/USD': '-0.11834%'}

# %% [markdown]
# ### Saving `Dictionary` data to a `JSON` file

# %%
def SaveToJSONfile(data: dict) -> json:
    timestr = time.strftime("%d-%m-%Y")
    try:
        with open(timestr + '-' +'PERCENT_CHANGE_IN_THE_LAST_24_HOURS.json', 'w') as file:
                json.dump(data, file)
    except FileNotFoundError as ex:
        print(ex)
        

SaveToJSONfile(DictionaryConversionRateChangePercentage)

# %% [markdown]
# ### Converting `Dictionary` to `JSON`

# %%
def ConvertingDictToJSON(datadict: dict) -> json:
    JSONUSDollarExchangeRatesTable = json.dumps(datadict)
    JSONUSDollarExchangeRatesTable
    dataUSDollarExchangeRatesTable = json.loads(JSONUSDollarExchangeRatesTable) 
    return dataUSDollarExchangeRatesTable

JSONConversionRateChangePercentage = ConvertingDictToJSON(DictionaryConversionRateChangePercentage)
ConvertingDictToJSON(DictionaryConversionRateChangePercentage)
# Out:
# {'EUR/USD': '+0.26880%',
#  'USD/JPY': '-0.01848%',
#  'GBP/USD': '-0.00218%',
#  'USD/CHF': '+0.01964%',
#  'USD/CAD': '-0.13320%',
#  'EUR/JPY': '+0.25027%',
#  'AUD/USD': '+0.05110%',
#  'CNY/USD': '-0.11834%'}

# %% [markdown]
# ### Creating `DataFrame` based on `JSON`

# %%
def CreateDataFrameFromJSONPercentageChange(json):
    dfPercentChangeIntheLast24Hours = pd.DataFrame.from_dict(json, orient="index")
    dfPercentChangeIntheLast24Hours.reset_index(inplace=True)
    dfPercentChangeIntheLast24Hours = dfPercentChangeIntheLast24Hours.set_axis(['ConversionCurrency', 'PercentChange'], axis=1)
    today_ts = pd.Timestamp.today()
    dfPercentChangeIntheLast24Hours['LOADINGDATA'] = today_ts
    dfPercentChangeIntheLast24Hours     

    return dfPercentChangeIntheLast24Hours

dfPercentChangeIntheLast24Hours = CreateDataFrameFromJSONPercentageChange(JSONConversionRateChangePercentage)
CreateDataFrameFromJSONPercentageChange(JSONConversionRateChangePercentage)
# Out:
#   ConversionCurrency PercentChange                LOADINGDATA
# 0            EUR/USD     +0.26880% 2023-12-25 18:27:08.303998
# 1            USD/JPY     -0.01848% 2023-12-25 18:27:08.303998
# 2            GBP/USD     -0.00218% 2023-12-25 18:27:08.303998
# 3            USD/CHF     +0.01964% 2023-12-25 18:27:08.303998
# 4            USD/CAD     -0.13320% 2023-12-25 18:27:08.303998
# 5            EUR/JPY     +0.25027% 2023-12-25 18:27:08.303998
# 6            AUD/USD     +0.05110% 2023-12-25 18:27:08.303998
# 7            CNY/USD     -0.11834% 2023-12-25 18:27:08.303998

# %% [markdown]
# ### Saving `DataFrame` to a `.csv` file

# %%
def SaveToCSVFile(dataframe):
    timestr = time.strftime("%d-%m-%Y")
    CSV = dataframe.to_csv(timestr + '-' + 'PercentChangeIntheLast24Hours.csv')
    return CSV

SaveToCSVFile(dfPercentChangeIntheLast24Hours)
